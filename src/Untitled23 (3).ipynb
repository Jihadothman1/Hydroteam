# %%
import dataretrieval.nwis as nwis
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import folium
import mplleaflet
from selenium import webdriver
from tqdm.notebook import tqdm
from folium.plugins import MarkerCluster

# %%
df = nwis.get_info(stateCd = 'UT')  
dfsites = df[0]
dfsites
# Out:
#       agency_cd          site_no  \
# 0          USGS         09163527
# 1          USGS         09163530
# 2          USGS         09163550
# 3          USGS         09163675
# 4          USGS         09163700
# ...         ...              ...
# 32695      USGS  415956112525201
# 32696      USGS  415956112532501
# 32697      USGS  415957112411001
# 32698      USGS  415958111242901
# 32699      USGS  415958112390301
#
#                                           station_nm site_tp_cd    lat_va  \
# 0           WEST BITTER CREEK NEAR HARLEY DOME, UTAH         ST  392035.0
# 1      COLORADO RIVER BELOW COLORADO-UTAH STATE LINE         ST  390518.0
# 2            HARLEY DOME WASH NEAR HARLEY DOME, UTAH         ST  390925.0
# 3          COTTONWOOD WASH AT I-70, NEAR CISCO, UTAH         ST  390454.0
# 4                        CISCO WASH NEAR CISCO, UTAH         ST  385750.0
# ...                                              ...        ...       ...
# 32695                              (B-15- 9)28cbc- 1         GW  415956.0
# 32696                              (B-15- 9)29dbc- 1         GW  415956.0
# 32697                              (B-15- 7)30cbc- 1         GW  415957.0
# 32698                              (A-15- 5)32dbb- 1         GW  415958.0
# 32699                              (B-15- 7)29dac- 1         GW  415958.0
#
#          long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 0      1090848.0   39.343032  -109.147336             M            F  ...
# 1      1090601.0   39.088317  -109.100945             M            F  ...
# 2      1090840.0   39.156927  -109.145114             M            F  ...
# 3      1091301.0   39.081652  -109.217615             M            F  ...
# 4      1092010.0   38.963873  -109.336784             M            F  ...
# ...          ...         ...          ...           ...          ...  ...
# 32695  1125252.0   41.998808  -112.881929             M            S  ...
# 32696  1125325.0   41.998808  -112.891096             M            S  ...
# 32697  1124110.0   41.999086  -112.686923             M            S  ...
# 32698  1112429.0   41.999377  -111.408818             M            T  ...
# 32699  1123903.0   41.999364  -112.651644             M            S  ...
#
#       local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  aqfr_cd  \
# 0                 Y            NaN    NNNNNNNN          NaN      NaN
# 1                 Y            NaN    NNNNNNNN          NaN      NaN
# 2                 Y            NaN    NNNNNNNN          NaN      NaN
# 3                 Y            NaN    NNNNNNNN          NaN      NaN
# 4                 Y            NaN    NNNNNNNN          NaN      NaN
# ...             ...            ...         ...          ...      ...
# 32695             Y              C    YNNNNNNN          NaN  100VLFL
# 32696             Y              C    YNNNNNNN          NaN  100VLFL
# 32697             Y              C    YNNNNNNN          NaN      NaN
# 32698             Y              U    NYNNNNNN          NaN      NaN
# 32699             Y              C    YNNNNNNN          NaN      NaN
#
#       aqfr_type_cd well_depth_va hole_depth_va  depth_src_cd  project_no
# 0              NaN           NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN           NaN         NaN
# 2              NaN           NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN           NaN         NaN
# 4              NaN           NaN           NaN           NaN         NaN
# ...            ...           ...           ...           ...         ...
# 32695          NaN         400.0           NaN             O         NaN
# 32696          NaN         480.0           NaN             O         NaN
# 32697          NaN         228.0           NaN           NaN         NaN
# 32698          NaN         191.0         191.0           NaN         NaN
# 32699          NaN         175.0           NaN           NaN         NaN
#
# [32700 rows x 42 columns]

# %%
#selecting only the groundwater sites
dfsitesGW = dfsites[dfsites["site_tp_cd"] == "GW"]
dfsitesGW
# Out:
#       agency_cd          site_no          station_nm site_tp_cd    lat_va  \
# 993        USGS  365954110163301   (D-43-15)32dcd- 1         GW  365954.0
# 994        USGS  370000113273301   (C-43-14)31ddd- 1         GW  370000.0
# 995        USGS  370001112575901       B-42-06 32BDB         GW  370001.0
# 996        USGS  370006111300401   (D-44- 4) 8bac- 1         GW  370006.0
# 1000       USGS  370010111302501   (D-44- 4) 7aab- 1         GW  370010.0
# ...         ...              ...                 ...        ...       ...
# 32695      USGS  415956112525201   (B-15- 9)28cbc- 1         GW  415956.0
# 32696      USGS  415956112532501   (B-15- 9)29dbc- 1         GW  415956.0
# 32697      USGS  415957112411001   (B-15- 7)30cbc- 1         GW  415957.0
# 32698      USGS  415958111242901   (A-15- 5)32dbb- 1         GW  415958.0
# 32699      USGS  415958112390301   (B-15- 7)29dac- 1         GW  415958.0
#
#          long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 993    1101633.0   36.998334  -110.276521             M            S  ...
# 994    1132733.0   36.999983  -113.459952             M            F  ...
# 995    1125759.0   37.000262  -112.967159             M            S  ...
# 996    1113004.0   37.001654  -111.501827             M            S  ...
# 1000   1113025.0   37.002765  -111.507661             M            F  ...
# ...          ...         ...          ...           ...          ...  ...
# 32695  1125252.0   41.998808  -112.881929             M            S  ...
# 32696  1125325.0   41.998808  -112.891096             M            S  ...
# 32697  1124110.0   41.999086  -112.686923             M            S  ...
# 32698  1112429.0   41.999377  -111.408818             M            T  ...
# 32699  1123903.0   41.999364  -112.651644             M            S  ...
#
#       local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  aqfr_cd  \
# 993               Y              C    NNNNNNNN   N300COPLTS  310DCLL
# 994               Y              C    YNNNNYNN          NaN      NaN
# 995               Y              C    YYYYNNNN          NaN  111ALVM
# 996               Y              C      Y    Y          NaN  227GLNC
# 1000              Y              C    YYNNNYNN          NaN      NaN
# ...             ...            ...         ...          ...      ...
# 32695             Y              C    YNNNNNNN          NaN  100VLFL
# 32696             Y              C    YNNNNNNN          NaN  100VLFL
# 32697             Y              C    YNNNNNNN          NaN      NaN
# 32698             Y              U    NYNNNNNN          NaN      NaN
# 32699             Y              C    YNNNNNNN          NaN      NaN
#
#       aqfr_type_cd well_depth_va hole_depth_va  depth_src_cd  project_no
# 993              U         120.0         120.0             R   474923900
# 994            NaN          14.0           NaN           NaN         NaN
# 995            NaN          84.0          84.0           NaN         KAN
# 996              X           NaN           NaN           NaN   971600203
# 1000           NaN         800.0         800.0             D   464900200
# ...            ...           ...           ...           ...         ...
# 32695          NaN         400.0           NaN             O         NaN
# 32696          NaN         480.0           NaN             O         NaN
# 32697          NaN         228.0           NaN           NaN         NaN
# 32698          NaN         191.0         191.0           NaN         NaN
# 32699          NaN         175.0           NaN           NaN         NaN
#
# [22739 rows x 42 columns]

# %%
# here I am dropping all the dupliats based on site ID. inplace is used to replace the dataframe:
dfsitesGW.drop_duplicates(subset=['site_no'], keep='first', inplace = True)


# in all cases, I am dropping all the sites that have no coordinates
dfsitesGW.dropna(subset=['dec_lat_va', 'dec_long_va'], inplace=True)

dfsitesGW
# Out:
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\2988894916.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsitesGW.drop_duplicates(subset=['site_no'], keep='first', inplace = True)
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\2988894916.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsitesGW.dropna(subset=['dec_lat_va', 'dec_long_va'], inplace=True)
#       agency_cd          site_no          station_nm site_tp_cd    lat_va  \
# 993        USGS  365954110163301   (D-43-15)32dcd- 1         GW  365954.0
# 994        USGS  370000113273301   (C-43-14)31ddd- 1         GW  370000.0
# 995        USGS  370001112575901       B-42-06 32BDB         GW  370001.0
# 996        USGS  370006111300401   (D-44- 4) 8bac- 1         GW  370006.0
# 1000       USGS  370010111302501   (D-44- 4) 7aab- 1         GW  370010.0
# ...         ...              ...                 ...        ...       ...
# 32695      USGS  415956112525201   (B-15- 9)28cbc- 1         GW  415956.0
# 32696      USGS  415956112532501   (B-15- 9)29dbc- 1         GW  415956.0
# 32697      USGS  415957112411001   (B-15- 7)30cbc- 1         GW  415957.0
# 32698      USGS  415958111242901   (A-15- 5)32dbb- 1         GW  415958.0
# 32699      USGS  415958112390301   (B-15- 7)29dac- 1         GW  415958.0
#
#          long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 993    1101633.0   36.998334  -110.276521             M            S  ...
# 994    1132733.0   36.999983  -113.459952             M            F  ...
# 995    1125759.0   37.000262  -112.967159             M            S  ...
# 996    1113004.0   37.001654  -111.501827             M            S  ...
# 1000   1113025.0   37.002765  -111.507661             M            F  ...
# ...          ...         ...          ...           ...          ...  ...
# 32695  1125252.0   41.998808  -112.881929             M            S  ...
# 32696  1125325.0   41.998808  -112.891096             M            S  ...
# 32697  1124110.0   41.999086  -112.686923             M            S  ...
# 32698  1112429.0   41.999377  -111.408818             M            T  ...
# 32699  1123903.0   41.999364  -112.651644             M            S  ...
#
#       local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  aqfr_cd  \
# 993               Y              C    NNNNNNNN   N300COPLTS  310DCLL
# 994               Y              C    YNNNNYNN          NaN      NaN
# 995               Y              C    YYYYNNNN          NaN  111ALVM
# 996               Y              C      Y    Y          NaN  227GLNC
# 1000              Y              C    YYNNNYNN          NaN      NaN
# ...             ...            ...         ...          ...      ...
# 32695             Y              C    YNNNNNNN          NaN  100VLFL
# 32696             Y              C    YNNNNNNN          NaN  100VLFL
# 32697             Y              C    YNNNNNNN          NaN      NaN
# 32698             Y              U    NYNNNNNN          NaN      NaN
# 32699             Y              C    YNNNNNNN          NaN      NaN
#
#       aqfr_type_cd well_depth_va hole_depth_va  depth_src_cd  project_no
# 993              U         120.0         120.0             R   474923900
# 994            NaN          14.0           NaN           NaN         NaN
# 995            NaN          84.0          84.0           NaN         KAN
# 996              X           NaN           NaN           NaN   971600203
# 1000           NaN         800.0         800.0             D   464900200
# ...            ...           ...           ...           ...         ...
# 32695          NaN         400.0           NaN             O         NaN
# 32696          NaN         480.0           NaN             O         NaN
# 32697          NaN         228.0           NaN           NaN         NaN
# 32698          NaN         191.0         191.0           NaN         NaN
# 32699          NaN         175.0           NaN           NaN         NaN
#
# [22737 rows x 42 columns]

# %%
#minimizing the data to work with a small dataset
new_df = dfsitesGW.iloc[:30]
new_df
# Out:
#      agency_cd          site_no          station_nm site_tp_cd    lat_va  \
# 993       USGS  365954110163301   (D-43-15)32dcd- 1         GW  365954.0
# 994       USGS  370000113273301   (C-43-14)31ddd- 1         GW  370000.0
# 995       USGS  370001112575901       B-42-06 32BDB         GW  370001.0
# 996       USGS  370006111300401   (D-44- 4) 8bac- 1         GW  370006.0
# 1000      USGS  370010111302501   (D-44- 4) 7aab- 1         GW  370010.0
# 1001      USGS  370010113002001    (C-43-10)32dca-1         GW  370010.0
# 1003      USGS  370017113002001    (C-43-10)32dba-1         GW  370017.0
# 1006      USGS  370021110174201   (D-43-15)31acc- 1         GW  370021.0
# 1008      USGS  370026110173801   (D-43-15)31aca- 1         GW  370026.0
# 1011      USGS  370033111374701    (D-44- 3) 6cac-1         GW  370033.0
# 1012      USGS  370034113290801   (C-43-15)25cdd- 1         GW  370034.0
# 1014      USGS  370036113282801   (C-43-14)31bbb- 1         GW  370036.0
# 1015      USGS  370037113281401   (C-43-14)31bab- 1         GW  370037.0
# 1016      USGS  370045113284201   (C-43-15)25ddd- 1         GW  370045.0
# 1017      USGS  370050112274501   (C-44- 5) 6cbb- 1         GW  370050.0
# 1019      USGS  370102111331201    (D-44- 3) 2bad-1         GW  370102.0
# 1021      USGS  370116110183301   (D-43-14)25adc- 1         GW  370116.0
# 1022      USGS  370120113555201   (C-43-19)25bbb- 1         GW  370120.0
# 1023      USGS  370125111360801   (D-43- 3)32dca- 2         GW  370125.0
# 1024      USGS  370125113190001   (C-43-13)28ab - 1         GW  370125.0
# 1025      USGS  370125113290401   (C-43-15)24dcc- 1         GW  370124.0
# 1026      USGS  370132110182001   (D-43-15)30bbb- 1         GW  370132.0
# 1027      USGS  370140113192801   (C-43-13)21cca- 1         GW  370140.0
# 1029      USGS  370147113373001   (C-43-16)33dab- 1         GW  370147.0
# 1032      USGS  370151111365101    (D-43- 3)32bbc-1         GW  370151.0
# 1033      USGS  370154113595701   (C-43-19)20bdc- 1         GW  370154.0
# 1034      USGS  370200113303501   (C-43-15)23bca- 1         GW  370200.0
# 1035      USGS  370201113301701   (C-43-15)23bda- 1         GW  370201.0
# 1036      USGS  370204113310701   (C-43-15)23bcb- 1         GW  370204.0
# 1037      USGS  370207113370801   (C-43-16)23bbc- 1         GW  370207.0
#
#         long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 993   1101633.0   36.998334  -110.276521             M            S  ...
# 994   1132733.0   36.999983  -113.459952             M            F  ...
# 995   1125759.0   37.000262  -112.967159             M            S  ...
# 996   1113004.0   37.001654  -111.501827             M            S  ...
# 1000  1113025.0   37.002765  -111.507661             M            F  ...
# 1001  1130020.0   37.002778  -113.005556             U            U  ...
# 1003  1130020.0   37.004722  -113.005556             U            U  ...
# 1006  1101742.0   37.005833  -110.295688             M            S  ...
# 1008  1101738.0   37.007222  -110.294576             M            S  ...
# 1011  1113747.0   37.009167  -111.629722             U            U  ...
# 1012  1132908.0   37.009427  -113.486341             G            R  ...
# 1014  1132828.0   37.009983  -113.475230             M            F  ...
# 1015  1132814.0   37.010260  -113.471341             M            S  ...
# 1016  1132842.0   37.012483  -113.479119             M            F  ...
# 1017  1122745.0   37.013875  -112.463256             M            F  ...
# 1019  1113312.0   37.017222  -111.553333             U            U  ...
# 1021  1101833.0   37.021111  -110.309854             M            S  ...
# 1022  1135552.0   37.022199  -113.931911             M            F  ...
# 1023  1113608.0   37.023597  -111.602942             M            F  ...
# 1024  1131900.0   37.023595  -113.317449             M            F  ...
# 1025  1132857.0   37.023316  -113.483286             M            F  ...
# 1026  1101820.0   37.025555  -110.306243             M            S  ...
# 1027  1131928.0   37.027761  -113.325227             M            S  ...
# 1029  1133730.0   37.029703  -113.625792             M            F  ...
# 1032  1113651.0   37.030833  -111.614167             U            U  ...
# 1033  1135957.0   37.031642  -113.999968             M            S  ...
# 1034  1133035.0   37.033316  -113.510509             M            F  ...
# 1035  1133017.0   37.033593  -113.505508             M            F  ...
# 1036  1133107.0   37.034427  -113.519398             M            F  ...
# 1037  1133708.0   37.035258  -113.619680             M            F  ...
#
#      local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  aqfr_cd  \
# 993              Y              C    NNNNNNNN   N300COPLTS  310DCLL
# 994              Y              C    YNNNNYNN          NaN      NaN
# 995              Y              C    YYYYNNNN          NaN  111ALVM
# 996              Y              C      Y    Y          NaN  227GLNC
# 1000             Y              C    YYNNNYNN          NaN      NaN
# 1001             Y              U         NaN          NaN      NaN
# 1003             Y              U         NaN          NaN      NaN
# 1006             Y              C    YNNNNNNN          NaN  310DCLL
# 1008             Y              C    YYNYNNNN          NaN  111ALVM
# 1011             Y              U         NaN          NaN      NaN
# 1012             Y              C      Y    Y          NaN      NaN
# 1014             Y              C    NYNNNYNN          NaN      NaN
# 1015             Y              C      YY   Y          NaN  100ALVM
# 1016             Y              C    YYNNNYNN          NaN      NaN
# 1017             Y              U    YYNNNYNN          NaN      NaN
# 1019             Y              U         NaN          NaN      NaN
# 1021             Y              C    NNNNNNNN          NaN      NaN
# 1022             Y              C    YYNNNYNN          NaN      NaN
# 1023             Y              U    YNNNNNNN          NaN      NaN
# 1024             Y              C    NYNNNNNN          NaN      NaN
# 1025             Y              C    YNNNNYNN          NaN      NaN
# 1026             Y              C    NNNNNNNN          NaN  111ALVM
# 1027             Y              C    YYNNNYNN          NaN  231MONV
# 1029             Y              C    YNNNNYNN          NaN      NaN
# 1032             Y              U         NaN          NaN      NaN
# 1033             Y              C    YYNNNNNN          NaN      NaN
# 1034             Y              C    NNNNNNNN          NaN      NaN
# 1035             Y              C    YNNNNYNN          NaN      NaN
# 1036             Y              C    YYNNNNNN          NaN      NaN
# 1037             Y              C    YNNNNNNN          NaN      NaN
#
#      aqfr_type_cd well_depth_va hole_depth_va  depth_src_cd  project_no
# 993             U         120.0         120.0             R   474923900
# 994           NaN          14.0           NaN           NaN         NaN
# 995           NaN          84.0          84.0           NaN         KAN
# 996             X           NaN           NaN           NaN   971600203
# 1000          NaN         800.0         800.0             D   464900200
# 1001          NaN           NaN           NaN           NaN  2018PSSWUD
# 1003          NaN           NaN           NaN           NaN  2018PSSWUD
# 1006            U         225.0         225.0             O   474923900
# 1008            U          50.0          60.0             D   474923900
# 1011          NaN           NaN           NaN           NaN  2018PSSWUD
# 1012          NaN         384.0         405.0             L   971600203
# 1014          NaN           NaN           NaN           NaN   464900300
# 1015            X         200.0         290.0             D   971600203
# 1016          NaN         144.0           NaN           NaN   464900200
# 1017          NaN          80.0           NaN           NaN   464900200
# 1019          NaN           NaN           NaN           NaN  2018PSSWUD
# 1021            U           NaN           NaN           NaN   474923900
# 1022          NaN         818.0         818.0             S   474921900
# 1023          NaN           NaN           NaN           NaN         NaN
# 1024          NaN        3000.0           NaN           NaN         NaN
# 1025          NaN           NaN           NaN           NaN   464900200
# 1026            U          62.0          62.0             R   474923900
# 1027          NaN         185.0         185.0             D   474923200
# 1029          NaN          45.0           NaN             D         NaN
# 1032          NaN           NaN           NaN           NaN  2018PSSWUD
# 1033          NaN         137.0         137.0             D   474921300
# 1034          NaN         370.0           NaN           NaN         NaN
# 1035          NaN           NaN           NaN           NaN   464900200
# 1036          NaN         400.0           NaN           NaN         NaN
# 1037          NaN          55.0           NaN             D         NaN
#
# [30 rows x 42 columns]

# %%
#calling all data from all sites obtained from the new_df
wellsDf = nwis.get_record(sites= new_df['site_no'], service='gwlevels', start = '1800-01-01') # select all  groundwater level data above 1800
wellsDf.head()
# Out:
# C:\Users\jihad\anaconda3\lib\site-packages\dataretrieval\utils.py:86: UserWarning: Warning: 1802 incomplete dates found, consider setting datetime_index to False.
#   warnings.warn(
#                                           agency_cd site_tp_cd      lev_dt  \
# site_no         datetime
# 370000113273301 NaN                            USGS         GW  1968-10-10
#                 NaN                            USGS         GW  1970-07-29
# 370006111300401 2007-03-14 14:39:00+00:00      USGS         GW  2007-03-14
#                 2008-03-20 15:09:00+00:00      USGS         GW  2008-03-20
#                 2010-03-24 14:53:00+00:00      USGS         GW  2010-03-24
#
#                                           lev_tm lev_tz_cd  lev_va  sl_lev_va  \
# site_no         datetime
# 370000113273301 NaN                          NaN     +0000   12.00        NaN
#                 NaN                          NaN     +0000   12.77        NaN
# 370006111300401 2007-03-14 14:39:00+00:00  14:39     +0000  110.11        NaN
#                 2008-03-20 15:09:00+00:00  15:09     +0000  110.39        NaN
#                 2010-03-24 14:53:00+00:00  14:53     +0000  105.39        NaN
#
#                                            sl_datum_cd lev_status_cd  \
# site_no         datetime
# 370000113273301 NaN                                NaN             1
#                 NaN                                NaN             1
# 370006111300401 2007-03-14 14:39:00+00:00          NaN             1
#                 2008-03-20 15:09:00+00:00          NaN             1
#                 2010-03-24 14:53:00+00:00          NaN             1
#
#                                           lev_agency_cd lev_dt_acy_cd  \
# site_no         datetime
# 370000113273301 NaN                                 NaN             D
#                 NaN                                 NaN             D
# 370006111300401 2007-03-14 14:39:00+00:00          USGS             m
#                 2008-03-20 15:09:00+00:00          USGS             m
#                 2010-03-24 14:53:00+00:00          USGS             m
#
#                                            lev_acy_cd lev_src_cd lev_meth_cd  \
# site_no         datetime
# 370000113273301 NaN                               NaN        NaN           Z
#                 NaN                               NaN        NaN           Z
# 370006111300401 2007-03-14 14:39:00+00:00         NaN          S           S
#                 2008-03-20 15:09:00+00:00         NaN          S           S
#                 2010-03-24 14:53:00+00:00         NaN          S           S
#
#                                           lev_age_cd
# site_no         datetime
# 370000113273301 NaN                                A
#                 NaN                                A
# 370006111300401 2007-03-14 14:39:00+00:00          A
#                 2008-03-20 15:09:00+00:00          A
#                 2010-03-24 14:53:00+00:00          A

# %%
# gwWellsDf = wellsDf[['site_tp_cd','lev_va','lev_dt']]
# gwWellsDf = gwWellsDf.reset_index(drop=False)
# gwWellsDf.set_index('site_no', inplace = True)
# gwWellsDf['countno'] = None
# new_df['countno'] = None
# gwWellsDf.dropna(subset=['lev_va'], inplace=True)

# for site_no in gwWellsDf.index.unique():
#     gwWellsSiteDf = gwWellsDf.loc[gwWellsDf.index == site_no]
#     gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
#     gwWellsSiteDf.set_index('lev_dt', inplace = True )
#     gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
#     print(site_no)
#     plt.plot(gwWellsSiteDf.index, gwWellsSiteDf['lev_va'], label=site_no)
#     plt.legend()
#     plt.xlabel('DateTime')
#     plt.ylabel('Depth')
#     plt.title('Time Series Data of wells groundwater level')
#     plt.show()    
    
# #dropping duplicates from the original dataframe gwWellsDf to be able to have a table of number of counts of each site
#     num_obs = gwWellsSiteDf.shape[0]    
#     gwWellsDf.loc[site_no, 'countno'] = num_obs

# %%
# gwWellsDf = wellsDf[['site_tp_cd','lev_va','lev_dt']]
# gwWellsDf = gwWellsDf.reset_index(drop=False)
# gwWellsDf.set_index('site_no', inplace = True)

# #creating new columns in the original table for start and end dates of recording
# gwWellsDf['startdate'] = None
# gwWellsDf['enddate'] = None

# #define the new columns as datetime
# gwWellsDf['startdate']=pd.to_datetime(gwWellsDf['startdate'])
# gwWellsDf['enddate']=pd.to_datetime(gwWellsDf['lev_dt'])


# #creating new count columns in both tables
# gwWellsDf['countno'] = None
# new_df['countno'] = None
# gwWellsDf.dropna(subset=['lev_va'], inplace=True)

# for site_no in gwWellsDf.index.unique():
#     gwWellsSiteDf = gwWellsDf.loc[gwWellsDf.index == site_no]
#     gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
#     start_date = gwWellsSiteDf['lev_dt'].min()
#     end_date = gwWellsSiteDf['lev_dt'].max()
#     print(site_no)
#     print(start_date)
#     print(end_date)
#     gwWellsSiteDf.set_index('lev_dt', inplace = True )
#     gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)

#     plt.plot(gwWellsSiteDf.index, gwWellsSiteDf['lev_va'], label=site_no)
#     plt.legend()
#     plt.xlabel('DateTime')
#     plt.ylabel('Depth')
#     plt.title('Time Series Data of wells groundwater level')
#     plt.show()    
    
# #dropping duplicates from the original dataframe gwWellsDf to be able to have a table of number of counts of each site
#     num_obs = gwWellsSiteDf.shape[0]    
#     gwWellsDf.loc[site_no, 'startdate'] = start_date
#     gwWellsDf.loc[site_no, 'enddate'] = end_date
#     gwWellsDf.loc[site_no, 'countno'] = num_obs

# %%
gwWellsDf = wellsDf[['site_tp_cd','lev_va','lev_dt']]
gwWellsDf = gwWellsDf.reset_index(drop=False)
gwWellsDf.set_index('site_no', inplace = True)



#creating new columns in the original table for start and end dates of recording
gwWellsDf['startdate'] = None
gwWellsDf['enddate'] = None

#define the new columns as datetime
gwWellsDf['startdate']=pd.to_datetime(gwWellsDf['startdate'])
gwWellsDf['enddate']=pd.to_datetime(gwWellsDf['lev_dt'])


#creating new count columns in both tables
gwWellsDf['countno'] = None
gwWellsDf['recentcount'] = None
new_df['countno'] = None
new_df['recentcount'] = None
gwWellsDf.dropna(subset=['lev_va'], inplace=True)

for site_no in gwWellsDf.index.unique():
    gwWellsSiteDf = gwWellsDf.loc[gwWellsDf.index == site_no]
    gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
    start_date = gwWellsSiteDf['lev_dt'].min()
    end_date = gwWellsSiteDf['lev_dt'].max()
    print(site_no)
    print(start_date)
    print(end_date)
    gwWellsSiteDf.set_index('lev_dt', inplace = True )
    gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)

    plt.plot(gwWellsSiteDf.index, gwWellsSiteDf['lev_va'], label=site_no)
    plt.legend()
    plt.xlabel('DateTime')
    plt.ylabel('Depth')
    plt.title('Time Series Data of wells groundwater level')
    plt.show()    

    num_obs = gwWellsSiteDf.shape[0]
    gwWellsDf.loc[site_no, 'startdate'] = start_date
    gwWellsDf.loc[site_no, 'enddate'] = end_date
    gwWellsDf.loc[site_no, 'countno'] = num_obs 
    
    
    
    gwWellsSiteDf = gwWellsSiteDf.loc['2010-01-01':]
    recent_num_obs = gwWellsSiteDf.shape[0]
    gwWellsDf.loc[site_no, 'recentcount'] = recent_num_obs
    
    
#dropping duplicates from the original dataframe gwWellsDf to be able to have a table of number of counts of each site
#     num_obs = gwWellsSiteDf.shape[0]    
#     gwWellsDf.loc[site_no, 'startdate'] = start_date
#     gwWellsDf.loc[site_no, 'enddate'] = end_date
#     gwWellsDf.loc[site_no, 'countno'] = num_obs
# Out:
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['countno'] = None
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['recentcount'] = None
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370000113273301
# 1968-10-10 00:00:00
# 1970-07-29 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370006111300401
# 1992-03-30 00:00:00
# 2022-03-30 00:00:00
# 370010111302501
# 1964-07-15 00:00:00
# 1990-03-17 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:48: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   gwWellsSiteDf = gwWellsSiteDf.loc['2010-01-01':]
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370021110174201
# 1996-08-26 00:00:00
# 1996-08-26 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370026110173801
# 1996-08-26 00:00:00
# 1996-08-26 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370034113290801
# 2005-02-24 00:00:00
# 2005-02-24 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370037113281401
# 2003-02-24 00:00:00
# 2023-02-14 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370045113284201
# 1960-11-16 00:00:00
# 2001-02-27 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:48: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   gwWellsSiteDf = gwWellsSiteDf.loc['2010-01-01':]
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370050112274501
# 1935-09-10 00:00:00
# 2022-03-02 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:48: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   gwWellsSiteDf = gwWellsSiteDf.loc['2010-01-01':]
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370120113555201
# 1994-02-26 00:00:00
# 1994-02-26 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:48: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   gwWellsSiteDf = gwWellsSiteDf.loc['2010-01-01':]
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370125111360801
# 1963-10-10 00:00:00
# 1980-10-13 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370125113290401
# 1984-03-28 00:00:00
# 2004-02-25 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370140113192801
# 1962-09-21 00:00:00
# 1997-02-28 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:48: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   gwWellsSiteDf = gwWellsSiteDf.loc['2010-01-01':]
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370147113373001
# 1966-01-16 00:00:00
# 1970-07-28 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370154113595701
# 1958-02-06 00:00:00
# 1958-02-06 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370201113301701
# 1984-03-28 00:00:00
# 1986-09-26 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370204113310701
# 1972-05-25 00:00:00
# 1972-05-25 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)
# 370207113370801
# 1966-01-08 00:00:00
# 1966-01-08 00:00:00
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf['lev_dt']=pd.to_datetime(gwWellsSiteDf['lev_dt'])
# C:\Users\jihad\AppData\Local\Temp\ipykernel_36056\3826170695.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwWellsSiteDf.dropna(subset=['lev_va'], inplace=True)

# %%
gwWellsDf
# Out:
#                                  datetime site_tp_cd  lev_va      lev_dt  \
# site_no
# 370000113273301                       NaT         GW   12.00  1968-10-10
# 370000113273301                       NaT         GW   12.77  1970-07-29
# 370006111300401 2007-03-14 14:39:00+00:00         GW  110.11  2007-03-14
# 370006111300401 2008-03-20 15:09:00+00:00         GW  110.39  2008-03-20
# 370006111300401 2010-03-24 14:53:00+00:00         GW  105.39  2010-03-24
# ...                                   ...        ...     ...         ...
# 370201113301701                       NaT         GW  210.28  1985-02-15
# 370201113301701                       NaT         GW  211.96  1985-10-11
# 370201113301701                       NaT         GW  204.98  1986-09-26
# 370204113310701                       NaT         GW  200.00  1972-05-25
# 370207113370801                       NaT         GW    2.00  1966-01-08
#
#                  startdate    enddate countno recentcount
# site_no
# 370000113273301 1968-10-10 1970-07-29       2           0
# 370000113273301 1968-10-10 1970-07-29       2           0
# 370006111300401 1992-03-30 2022-03-30      32          13
# 370006111300401 1992-03-30 2022-03-30      32          13
# 370006111300401 1992-03-30 2022-03-30      32          13
# ...                    ...        ...     ...         ...
# 370201113301701 1984-03-28 1986-09-26       4           0
# 370201113301701 1984-03-28 1986-09-26       4           0
# 370201113301701 1984-03-28 1986-09-26       4           0
# 370204113310701 1972-05-25 1972-05-25       1           0
# 370207113370801 1966-01-08 1966-01-08       1           0
#
# [1851 rows x 8 columns]

# %%
gwWellsDf = gwWellsDf.reset_index(drop=False)
gwWellsDf.drop_duplicates(subset=['site_no'], keep='first', inplace = True)
gwWellsDf
# Out:
#               site_no                  datetime site_tp_cd  lev_va  \
# 0     370000113273301                       NaT         GW   12.00
# 2     370006111300401 2007-03-14 14:39:00+00:00         GW  110.11
# 34    370010111302501                       NaT         GW  357.07
# 841   370021110174201                       NaT         GW   47.00
# 842   370026110173801                       NaT         GW   36.00
# 843   370034113290801                       NaT         GW   81.07
# 844   370037113281401 2008-02-20 21:31:00+00:00         GW  178.94
# 865   370045113284201 1997-02-20 19:15:00+00:00         GW  127.70
# 915   370050112274501 1997-03-24 19:00:00+00:00         GW   52.10
# 1036  370120113555201                       NaT         GW  763.99
# 1037  370125111360801                       NaT         GW  310.21
# 1815  370125113290401 1998-02-28 22:00:00+00:00         GW  149.42
# 1839  370140113192801                       NaT         GW  160.00
# 1841  370147113373001                       NaT         GW   30.00
# 1844  370154113595701                       NaT         GW   84.00
# 1845  370201113301701                       NaT         GW  215.03
# 1849  370204113310701                       NaT         GW  200.00
# 1850  370207113370801                       NaT         GW    2.00
#
#           lev_dt  startdate    enddate countno recentcount
# 0     1968-10-10 1968-10-10 1970-07-29       2           0
# 2     2007-03-14 1992-03-30 2022-03-30      32          13
# 34    1964-07-15 1964-07-15 1990-03-17     807           0
# 841   1996-08-26 1996-08-26 1996-08-26       1           0
# 842   1996-08-26 1996-08-26 1996-08-26       1           0
# 843   2005-02-24 2005-02-24 2005-02-24       1           0
# 844   2008-02-20 2003-02-24 2023-02-14      21          14
# 865   1997-02-20 1960-11-16 2001-02-27      50           0
# 915   1997-03-24 1935-09-10 2022-03-02     121          13
# 1036  1994-02-26 1994-02-26 1994-02-26       1           0
# 1037  1963-10-10 1963-10-10 1980-10-13     778           0
# 1815  1998-02-28 1984-03-28 2004-02-25      24           0
# 1839  1962-09-21 1962-09-21 1997-02-28       2           0
# 1841  1966-01-16 1966-01-16 1970-07-28       3           0
# 1844  1958-02-06 1958-02-06 1958-02-06       1           0
# 1845  1984-03-28 1984-03-28 1986-09-26       4           0
# 1849  1972-05-25 1972-05-25 1972-05-25       1           0
# 1850  1966-01-08 1966-01-08 1966-01-08       1           0

# %%
new_df
# Out:
#      agency_cd          site_no          station_nm site_tp_cd    lat_va  \
# 993       USGS  365954110163301   (D-43-15)32dcd- 1         GW  365954.0
# 994       USGS  370000113273301   (C-43-14)31ddd- 1         GW  370000.0
# 995       USGS  370001112575901       B-42-06 32BDB         GW  370001.0
# 996       USGS  370006111300401   (D-44- 4) 8bac- 1         GW  370006.0
# 1000      USGS  370010111302501   (D-44- 4) 7aab- 1         GW  370010.0
# 1001      USGS  370010113002001    (C-43-10)32dca-1         GW  370010.0
# 1003      USGS  370017113002001    (C-43-10)32dba-1         GW  370017.0
# 1006      USGS  370021110174201   (D-43-15)31acc- 1         GW  370021.0
# 1008      USGS  370026110173801   (D-43-15)31aca- 1         GW  370026.0
# 1011      USGS  370033111374701    (D-44- 3) 6cac-1         GW  370033.0
# 1012      USGS  370034113290801   (C-43-15)25cdd- 1         GW  370034.0
# 1014      USGS  370036113282801   (C-43-14)31bbb- 1         GW  370036.0
# 1015      USGS  370037113281401   (C-43-14)31bab- 1         GW  370037.0
# 1016      USGS  370045113284201   (C-43-15)25ddd- 1         GW  370045.0
# 1017      USGS  370050112274501   (C-44- 5) 6cbb- 1         GW  370050.0
# 1019      USGS  370102111331201    (D-44- 3) 2bad-1         GW  370102.0
# 1021      USGS  370116110183301   (D-43-14)25adc- 1         GW  370116.0
# 1022      USGS  370120113555201   (C-43-19)25bbb- 1         GW  370120.0
# 1023      USGS  370125111360801   (D-43- 3)32dca- 2         GW  370125.0
# 1024      USGS  370125113190001   (C-43-13)28ab - 1         GW  370125.0
# 1025      USGS  370125113290401   (C-43-15)24dcc- 1         GW  370124.0
# 1026      USGS  370132110182001   (D-43-15)30bbb- 1         GW  370132.0
# 1027      USGS  370140113192801   (C-43-13)21cca- 1         GW  370140.0
# 1029      USGS  370147113373001   (C-43-16)33dab- 1         GW  370147.0
# 1032      USGS  370151111365101    (D-43- 3)32bbc-1         GW  370151.0
# 1033      USGS  370154113595701   (C-43-19)20bdc- 1         GW  370154.0
# 1034      USGS  370200113303501   (C-43-15)23bca- 1         GW  370200.0
# 1035      USGS  370201113301701   (C-43-15)23bda- 1         GW  370201.0
# 1036      USGS  370204113310701   (C-43-15)23bcb- 1         GW  370204.0
# 1037      USGS  370207113370801   (C-43-16)23bbc- 1         GW  370207.0
#
#         long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 993   1101633.0   36.998334  -110.276521             M            S  ...
# 994   1132733.0   36.999983  -113.459952             M            F  ...
# 995   1125759.0   37.000262  -112.967159             M            S  ...
# 996   1113004.0   37.001654  -111.501827             M            S  ...
# 1000  1113025.0   37.002765  -111.507661             M            F  ...
# 1001  1130020.0   37.002778  -113.005556             U            U  ...
# 1003  1130020.0   37.004722  -113.005556             U            U  ...
# 1006  1101742.0   37.005833  -110.295688             M            S  ...
# 1008  1101738.0   37.007222  -110.294576             M            S  ...
# 1011  1113747.0   37.009167  -111.629722             U            U  ...
# 1012  1132908.0   37.009427  -113.486341             G            R  ...
# 1014  1132828.0   37.009983  -113.475230             M            F  ...
# 1015  1132814.0   37.010260  -113.471341             M            S  ...
# 1016  1132842.0   37.012483  -113.479119             M            F  ...
# 1017  1122745.0   37.013875  -112.463256             M            F  ...
# 1019  1113312.0   37.017222  -111.553333             U            U  ...
# 1021  1101833.0   37.021111  -110.309854             M            S  ...
# 1022  1135552.0   37.022199  -113.931911             M            F  ...
# 1023  1113608.0   37.023597  -111.602942             M            F  ...
# 1024  1131900.0   37.023595  -113.317449             M            F  ...
# 1025  1132857.0   37.023316  -113.483286             M            F  ...
# 1026  1101820.0   37.025555  -110.306243             M            S  ...
# 1027  1131928.0   37.027761  -113.325227             M            S  ...
# 1029  1133730.0   37.029703  -113.625792             M            F  ...
# 1032  1113651.0   37.030833  -111.614167             U            U  ...
# 1033  1135957.0   37.031642  -113.999968             M            S  ...
# 1034  1133035.0   37.033316  -113.510509             M            F  ...
# 1035  1133017.0   37.033593  -113.505508             M            F  ...
# 1036  1133107.0   37.034427  -113.519398             M            F  ...
# 1037  1133708.0   37.035258  -113.619680             M            F  ...
#
#      gw_file_cd nat_aqfr_cd  aqfr_cd  aqfr_type_cd  well_depth_va  \
# 993    NNNNNNNN  N300COPLTS  310DCLL             U          120.0
# 994    YNNNNYNN         NaN      NaN           NaN           14.0
# 995    YYYYNNNN         NaN  111ALVM           NaN           84.0
# 996      Y    Y         NaN  227GLNC             X            NaN
# 1000   YYNNNYNN         NaN      NaN           NaN          800.0
# 1001        NaN         NaN      NaN           NaN            NaN
# 1003        NaN         NaN      NaN           NaN            NaN
# 1006   YNNNNNNN         NaN  310DCLL             U          225.0
# 1008   YYNYNNNN         NaN  111ALVM             U           50.0
# 1011        NaN         NaN      NaN           NaN            NaN
# 1012     Y    Y         NaN      NaN           NaN          384.0
# 1014   NYNNNYNN         NaN      NaN           NaN            NaN
# 1015     YY   Y         NaN  100ALVM             X          200.0
# 1016   YYNNNYNN         NaN      NaN           NaN          144.0
# 1017   YYNNNYNN         NaN      NaN           NaN           80.0
# 1019        NaN         NaN      NaN           NaN            NaN
# 1021   NNNNNNNN         NaN      NaN             U            NaN
# 1022   YYNNNYNN         NaN      NaN           NaN          818.0
# 1023   YNNNNNNN         NaN      NaN           NaN            NaN
# 1024   NYNNNNNN         NaN      NaN           NaN         3000.0
# 1025   YNNNNYNN         NaN      NaN           NaN            NaN
# 1026   NNNNNNNN         NaN  111ALVM             U           62.0
# 1027   YYNNNYNN         NaN  231MONV           NaN          185.0
# 1029   YNNNNYNN         NaN      NaN           NaN           45.0
# 1032        NaN         NaN      NaN           NaN            NaN
# 1033   YYNNNNNN         NaN      NaN           NaN          137.0
# 1034   NNNNNNNN         NaN      NaN           NaN          370.0
# 1035   YNNNNYNN         NaN      NaN           NaN            NaN
# 1036   YYNNNNNN         NaN      NaN           NaN          400.0
# 1037   YNNNNNNN         NaN      NaN           NaN           55.0
#
#      hole_depth_va depth_src_cd  project_no  countno  recentcount
# 993          120.0            R   474923900     None         None
# 994            NaN          NaN         NaN     None         None
# 995           84.0          NaN         KAN     None         None
# 996            NaN          NaN   971600203     None         None
# 1000         800.0            D   464900200     None         None
# 1001           NaN          NaN  2018PSSWUD     None         None
# 1003           NaN          NaN  2018PSSWUD     None         None
# 1006         225.0            O   474923900     None         None
# 1008          60.0            D   474923900     None         None
# 1011           NaN          NaN  2018PSSWUD     None         None
# 1012         405.0            L   971600203     None         None
# 1014           NaN          NaN   464900300     None         None
# 1015         290.0            D   971600203     None         None
# 1016           NaN          NaN   464900200     None         None
# 1017           NaN          NaN   464900200     None         None
# 1019           NaN          NaN  2018PSSWUD     None         None
# 1021           NaN          NaN   474923900     None         None
# 1022         818.0            S   474921900     None         None
# 1023           NaN          NaN         NaN     None         None
# 1024           NaN          NaN         NaN     None         None
# 1025           NaN          NaN   464900200     None         None
# 1026          62.0            R   474923900     None         None
# 1027         185.0            D   474923200     None         None
# 1029           NaN            D         NaN     None         None
# 1032           NaN          NaN  2018PSSWUD     None         None
# 1033         137.0            D   474921300     None         None
# 1034           NaN          NaN         NaN     None         None
# 1035           NaN          NaN   464900200     None         None
# 1036           NaN          NaN         NaN     None         None
# 1037           NaN            D         NaN     None         None
#
# [30 rows x 44 columns]

# %%
#merging the 2 tables to obtain only one table with count number
merged_df = pd.merge(new_df, gwWellsDf[['site_no', 'countno','startdate','enddate','recentcount']], on='site_no', how='left')
merged_df

merged_df['countno_x'].fillna(merged_df['countno_y'], inplace=True)
merged_df['countno_x'].fillna(0, inplace=True)

merged_df['recentcount_x'].fillna(merged_df['recentcount_y'], inplace=True)
merged_df['recentcount_x'].fillna(0, inplace=True)



merged_df['recentcount_x'] = merged_df['recentcount_x'].astype(int)

merged_df['countno_x'] = merged_df['countno_x'].astype(int)

merged_df.drop(columns=['countno_y'], inplace=True)
merged_df.rename(columns={'countno_x': 'count'}, inplace=True)



merged_df.drop(columns=['recentcount_y'], inplace=True)
merged_df.rename(columns={'recentcount_x': 'recentcount'}, inplace=True)


merged_df
# Out:
#    agency_cd          site_no          station_nm site_tp_cd    lat_va  \
# 0       USGS  365954110163301   (D-43-15)32dcd- 1         GW  365954.0
# 1       USGS  370000113273301   (C-43-14)31ddd- 1         GW  370000.0
# 2       USGS  370001112575901       B-42-06 32BDB         GW  370001.0
# 3       USGS  370006111300401   (D-44- 4) 8bac- 1         GW  370006.0
# 4       USGS  370010111302501   (D-44- 4) 7aab- 1         GW  370010.0
# 5       USGS  370010113002001    (C-43-10)32dca-1         GW  370010.0
# 6       USGS  370017113002001    (C-43-10)32dba-1         GW  370017.0
# 7       USGS  370021110174201   (D-43-15)31acc- 1         GW  370021.0
# 8       USGS  370026110173801   (D-43-15)31aca- 1         GW  370026.0
# 9       USGS  370033111374701    (D-44- 3) 6cac-1         GW  370033.0
# 10      USGS  370034113290801   (C-43-15)25cdd- 1         GW  370034.0
# 11      USGS  370036113282801   (C-43-14)31bbb- 1         GW  370036.0
# 12      USGS  370037113281401   (C-43-14)31bab- 1         GW  370037.0
# 13      USGS  370045113284201   (C-43-15)25ddd- 1         GW  370045.0
# 14      USGS  370050112274501   (C-44- 5) 6cbb- 1         GW  370050.0
# 15      USGS  370102111331201    (D-44- 3) 2bad-1         GW  370102.0
# 16      USGS  370116110183301   (D-43-14)25adc- 1         GW  370116.0
# 17      USGS  370120113555201   (C-43-19)25bbb- 1         GW  370120.0
# 18      USGS  370125111360801   (D-43- 3)32dca- 2         GW  370125.0
# 19      USGS  370125113190001   (C-43-13)28ab - 1         GW  370125.0
# 20      USGS  370125113290401   (C-43-15)24dcc- 1         GW  370124.0
# 21      USGS  370132110182001   (D-43-15)30bbb- 1         GW  370132.0
# 22      USGS  370140113192801   (C-43-13)21cca- 1         GW  370140.0
# 23      USGS  370147113373001   (C-43-16)33dab- 1         GW  370147.0
# 24      USGS  370151111365101    (D-43- 3)32bbc-1         GW  370151.0
# 25      USGS  370154113595701   (C-43-19)20bdc- 1         GW  370154.0
# 26      USGS  370200113303501   (C-43-15)23bca- 1         GW  370200.0
# 27      USGS  370201113301701   (C-43-15)23bda- 1         GW  370201.0
# 28      USGS  370204113310701   (C-43-15)23bcb- 1         GW  370204.0
# 29      USGS  370207113370801   (C-43-16)23bbc- 1         GW  370207.0
#
#       long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 0   1101633.0   36.998334  -110.276521             M            S  ...
# 1   1132733.0   36.999983  -113.459952             M            F  ...
# 2   1125759.0   37.000262  -112.967159             M            S  ...
# 3   1113004.0   37.001654  -111.501827             M            S  ...
# 4   1113025.0   37.002765  -111.507661             M            F  ...
# 5   1130020.0   37.002778  -113.005556             U            U  ...
# 6   1130020.0   37.004722  -113.005556             U            U  ...
# 7   1101742.0   37.005833  -110.295688             M            S  ...
# 8   1101738.0   37.007222  -110.294576             M            S  ...
# 9   1113747.0   37.009167  -111.629722             U            U  ...
# 10  1132908.0   37.009427  -113.486341             G            R  ...
# 11  1132828.0   37.009983  -113.475230             M            F  ...
# 12  1132814.0   37.010260  -113.471341             M            S  ...
# 13  1132842.0   37.012483  -113.479119             M            F  ...
# 14  1122745.0   37.013875  -112.463256             M            F  ...
# 15  1113312.0   37.017222  -111.553333             U            U  ...
# 16  1101833.0   37.021111  -110.309854             M            S  ...
# 17  1135552.0   37.022199  -113.931911             M            F  ...
# 18  1113608.0   37.023597  -111.602942             M            F  ...
# 19  1131900.0   37.023595  -113.317449             M            F  ...
# 20  1132857.0   37.023316  -113.483286             M            F  ...
# 21  1101820.0   37.025555  -110.306243             M            S  ...
# 22  1131928.0   37.027761  -113.325227             M            S  ...
# 23  1133730.0   37.029703  -113.625792             M            F  ...
# 24  1113651.0   37.030833  -111.614167             U            U  ...
# 25  1135957.0   37.031642  -113.999968             M            S  ...
# 26  1133035.0   37.033316  -113.510509             M            F  ...
# 27  1133017.0   37.033593  -113.505508             M            F  ...
# 28  1133107.0   37.034427  -113.519398             M            F  ...
# 29  1133708.0   37.035258  -113.619680             M            F  ...
#
#     aqfr_cd aqfr_type_cd  well_depth_va  hole_depth_va  depth_src_cd  \
# 0   310DCLL            U          120.0          120.0             R
# 1       NaN          NaN           14.0            NaN           NaN
# 2   111ALVM          NaN           84.0           84.0           NaN
# 3   227GLNC            X            NaN            NaN           NaN
# 4       NaN          NaN          800.0          800.0             D
# 5       NaN          NaN            NaN            NaN           NaN
# 6       NaN          NaN            NaN            NaN           NaN
# 7   310DCLL            U          225.0          225.0             O
# 8   111ALVM            U           50.0           60.0             D
# 9       NaN          NaN            NaN            NaN           NaN
# 10      NaN          NaN          384.0          405.0             L
# 11      NaN          NaN            NaN            NaN           NaN
# 12  100ALVM            X          200.0          290.0             D
# 13      NaN          NaN          144.0            NaN           NaN
# 14      NaN          NaN           80.0            NaN           NaN
# 15      NaN          NaN            NaN            NaN           NaN
# 16      NaN            U            NaN            NaN           NaN
# 17      NaN          NaN          818.0          818.0             S
# 18      NaN          NaN            NaN            NaN           NaN
# 19      NaN          NaN         3000.0            NaN           NaN
# 20      NaN          NaN            NaN            NaN           NaN
# 21  111ALVM            U           62.0           62.0             R
# 22  231MONV          NaN          185.0          185.0             D
# 23      NaN          NaN           45.0            NaN             D
# 24      NaN          NaN            NaN            NaN           NaN
# 25      NaN          NaN          137.0          137.0             D
# 26      NaN          NaN          370.0            NaN           NaN
# 27      NaN          NaN            NaN            NaN           NaN
# 28      NaN          NaN          400.0            NaN           NaN
# 29      NaN          NaN           55.0            NaN             D
#
#     project_no count recentcount  startdate    enddate
# 0    474923900     0           0        NaT        NaT
# 1          NaN     2           0 1968-10-10 1970-07-29
# 2          KAN     0           0        NaT        NaT
# 3    971600203    32          13 1992-03-30 2022-03-30
# 4    464900200   807           0 1964-07-15 1990-03-17
# 5   2018PSSWUD     0           0        NaT        NaT
# 6   2018PSSWUD     0           0        NaT        NaT
# 7    474923900     1           0 1996-08-26 1996-08-26
# 8    474923900     1           0 1996-08-26 1996-08-26
# 9   2018PSSWUD     0           0        NaT        NaT
# 10   971600203     1           0 2005-02-24 2005-02-24
# 11   464900300     0           0        NaT        NaT
# 12   971600203    21          14 2003-02-24 2023-02-14
# 13   464900200    50           0 1960-11-16 2001-02-27
# 14   464900200   121          13 1935-09-10 2022-03-02
# 15  2018PSSWUD     0           0        NaT        NaT
# 16   474923900     0           0        NaT        NaT
# 17   474921900     1           0 1994-02-26 1994-02-26
# 18         NaN   778           0 1963-10-10 1980-10-13
# 19         NaN     0           0        NaT        NaT
# 20   464900200    24           0 1984-03-28 2004-02-25
# 21   474923900     0           0        NaT        NaT
# 22   474923200     2           0 1962-09-21 1997-02-28
# 23         NaN     3           0 1966-01-16 1970-07-28
# 24  2018PSSWUD     0           0        NaT        NaT
# 25   474921300     1           0 1958-02-06 1958-02-06
# 26         NaN     0           0        NaT        NaT
# 27   464900200     4           0 1984-03-28 1986-09-26
# 28         NaN     1           0 1972-05-25 1972-05-25
# 29         NaN     1           0 1966-01-08 1966-01-08
#
# [30 rows x 46 columns]

# %%
merged_df['color']=None
color_mapper = lambda x: 'blue' if x == 'GW' else 'red'
merged_df['color'] = merged_df['site_tp_cd'].apply(color_mapper)
merged_df
# Out:
#    agency_cd          site_no          station_nm site_tp_cd    lat_va  \
# 0       USGS  365954110163301   (D-43-15)32dcd- 1         GW  365954.0
# 1       USGS  370000113273301   (C-43-14)31ddd- 1         GW  370000.0
# 2       USGS  370001112575901       B-42-06 32BDB         GW  370001.0
# 3       USGS  370006111300401   (D-44- 4) 8bac- 1         GW  370006.0
# 4       USGS  370010111302501   (D-44- 4) 7aab- 1         GW  370010.0
# 5       USGS  370010113002001    (C-43-10)32dca-1         GW  370010.0
# 6       USGS  370017113002001    (C-43-10)32dba-1         GW  370017.0
# 7       USGS  370021110174201   (D-43-15)31acc- 1         GW  370021.0
# 8       USGS  370026110173801   (D-43-15)31aca- 1         GW  370026.0
# 9       USGS  370033111374701    (D-44- 3) 6cac-1         GW  370033.0
# 10      USGS  370034113290801   (C-43-15)25cdd- 1         GW  370034.0
# 11      USGS  370036113282801   (C-43-14)31bbb- 1         GW  370036.0
# 12      USGS  370037113281401   (C-43-14)31bab- 1         GW  370037.0
# 13      USGS  370045113284201   (C-43-15)25ddd- 1         GW  370045.0
# 14      USGS  370050112274501   (C-44- 5) 6cbb- 1         GW  370050.0
# 15      USGS  370102111331201    (D-44- 3) 2bad-1         GW  370102.0
# 16      USGS  370116110183301   (D-43-14)25adc- 1         GW  370116.0
# 17      USGS  370120113555201   (C-43-19)25bbb- 1         GW  370120.0
# 18      USGS  370125111360801   (D-43- 3)32dca- 2         GW  370125.0
# 19      USGS  370125113190001   (C-43-13)28ab - 1         GW  370125.0
# 20      USGS  370125113290401   (C-43-15)24dcc- 1         GW  370124.0
# 21      USGS  370132110182001   (D-43-15)30bbb- 1         GW  370132.0
# 22      USGS  370140113192801   (C-43-13)21cca- 1         GW  370140.0
# 23      USGS  370147113373001   (C-43-16)33dab- 1         GW  370147.0
# 24      USGS  370151111365101    (D-43- 3)32bbc-1         GW  370151.0
# 25      USGS  370154113595701   (C-43-19)20bdc- 1         GW  370154.0
# 26      USGS  370200113303501   (C-43-15)23bca- 1         GW  370200.0
# 27      USGS  370201113301701   (C-43-15)23bda- 1         GW  370201.0
# 28      USGS  370204113310701   (C-43-15)23bcb- 1         GW  370204.0
# 29      USGS  370207113370801   (C-43-16)23bbc- 1         GW  370207.0
#
#       long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 0   1101633.0   36.998334  -110.276521             M            S  ...
# 1   1132733.0   36.999983  -113.459952             M            F  ...
# 2   1125759.0   37.000262  -112.967159             M            S  ...
# 3   1113004.0   37.001654  -111.501827             M            S  ...
# 4   1113025.0   37.002765  -111.507661             M            F  ...
# 5   1130020.0   37.002778  -113.005556             U            U  ...
# 6   1130020.0   37.004722  -113.005556             U            U  ...
# 7   1101742.0   37.005833  -110.295688             M            S  ...
# 8   1101738.0   37.007222  -110.294576             M            S  ...
# 9   1113747.0   37.009167  -111.629722             U            U  ...
# 10  1132908.0   37.009427  -113.486341             G            R  ...
# 11  1132828.0   37.009983  -113.475230             M            F  ...
# 12  1132814.0   37.010260  -113.471341             M            S  ...
# 13  1132842.0   37.012483  -113.479119             M            F  ...
# 14  1122745.0   37.013875  -112.463256             M            F  ...
# 15  1113312.0   37.017222  -111.553333             U            U  ...
# 16  1101833.0   37.021111  -110.309854             M            S  ...
# 17  1135552.0   37.022199  -113.931911             M            F  ...
# 18  1113608.0   37.023597  -111.602942             M            F  ...
# 19  1131900.0   37.023595  -113.317449             M            F  ...
# 20  1132857.0   37.023316  -113.483286             M            F  ...
# 21  1101820.0   37.025555  -110.306243             M            S  ...
# 22  1131928.0   37.027761  -113.325227             M            S  ...
# 23  1133730.0   37.029703  -113.625792             M            F  ...
# 24  1113651.0   37.030833  -111.614167             U            U  ...
# 25  1135957.0   37.031642  -113.999968             M            S  ...
# 26  1133035.0   37.033316  -113.510509             M            F  ...
# 27  1133017.0   37.033593  -113.505508             M            F  ...
# 28  1133107.0   37.034427  -113.519398             M            F  ...
# 29  1133708.0   37.035258  -113.619680             M            F  ...
#
#    aqfr_type_cd well_depth_va  hole_depth_va  depth_src_cd  project_no count  \
# 0             U         120.0          120.0             R   474923900     0
# 1           NaN          14.0            NaN           NaN         NaN     2
# 2           NaN          84.0           84.0           NaN         KAN     0
# 3             X           NaN            NaN           NaN   971600203    32
# 4           NaN         800.0          800.0             D   464900200   807
# 5           NaN           NaN            NaN           NaN  2018PSSWUD     0
# 6           NaN           NaN            NaN           NaN  2018PSSWUD     0
# 7             U         225.0          225.0             O   474923900     1
# 8             U          50.0           60.0             D   474923900     1
# 9           NaN           NaN            NaN           NaN  2018PSSWUD     0
# 10          NaN         384.0          405.0             L   971600203     1
# 11          NaN           NaN            NaN           NaN   464900300     0
# 12            X         200.0          290.0             D   971600203    21
# 13          NaN         144.0            NaN           NaN   464900200    50
# 14          NaN          80.0            NaN           NaN   464900200   121
# 15          NaN           NaN            NaN           NaN  2018PSSWUD     0
# 16            U           NaN            NaN           NaN   474923900     0
# 17          NaN         818.0          818.0             S   474921900     1
# 18          NaN           NaN            NaN           NaN         NaN   778
# 19          NaN        3000.0            NaN           NaN         NaN     0
# 20          NaN           NaN            NaN           NaN   464900200    24
# 21            U          62.0           62.0             R   474923900     0
# 22          NaN         185.0          185.0             D   474923200     2
# 23          NaN          45.0            NaN             D         NaN     3
# 24          NaN           NaN            NaN           NaN  2018PSSWUD     0
# 25          NaN         137.0          137.0             D   474921300     1
# 26          NaN         370.0            NaN           NaN         NaN     0
# 27          NaN           NaN            NaN           NaN   464900200     4
# 28          NaN         400.0            NaN           NaN         NaN     1
# 29          NaN          55.0            NaN             D         NaN     1
#
#    recentcount  startdate    enddate  color
# 0            0        NaT        NaT   blue
# 1            0 1968-10-10 1970-07-29   blue
# 2            0        NaT        NaT   blue
# 3           13 1992-03-30 2022-03-30   blue
# 4            0 1964-07-15 1990-03-17   blue
# 5            0        NaT        NaT   blue
# 6            0        NaT        NaT   blue
# 7            0 1996-08-26 1996-08-26   blue
# 8            0 1996-08-26 1996-08-26   blue
# 9            0        NaT        NaT   blue
# 10           0 2005-02-24 2005-02-24   blue
# 11           0        NaT        NaT   blue
# 12          14 2003-02-24 2023-02-14   blue
# 13           0 1960-11-16 2001-02-27   blue
# 14          13 1935-09-10 2022-03-02   blue
# 15           0        NaT        NaT   blue
# 16           0        NaT        NaT   blue
# 17           0 1994-02-26 1994-02-26   blue
# 18           0 1963-10-10 1980-10-13   blue
# 19           0        NaT        NaT   blue
# 20           0 1984-03-28 2004-02-25   blue
# 21           0        NaT        NaT   blue
# 22           0 1962-09-21 1997-02-28   blue
# 23           0 1966-01-16 1970-07-28   blue
# 24           0        NaT        NaT   blue
# 25           0 1958-02-06 1958-02-06   blue
# 26           0        NaT        NaT   blue
# 27           0 1984-03-28 1986-09-26   blue
# 28           0 1972-05-25 1972-05-25   blue
# 29           0 1966-01-08 1966-01-08   blue
#
# [30 rows x 47 columns]

# %%
#subsetting the data of count above 100
df100 = merged_df[merged_df['count'] > 100]
df100


recentdf100 = merged_df[merged_df['recentcount'] > 100]
recentdf100
# Out:
# Empty DataFrame
# Columns: [agency_cd, site_no, station_nm, site_tp_cd, lat_va, long_va, dec_lat_va, dec_long_va, coord_meth_cd, coord_acy_cd, coord_datum_cd, dec_coord_datum_cd, district_cd, state_cd, county_cd, country_cd, land_net_ds, map_nm, map_scale_fc, alt_va, alt_meth_cd, alt_acy_va, alt_datum_cd, huc_cd, basin_cd, topo_cd, instruments_cd, construction_dt, inventory_dt, drain_area_va, contrib_drain_area_va, tz_cd, local_time_fg, reliability_cd, gw_file_cd, nat_aqfr_cd, aqfr_cd, aqfr_type_cd, well_depth_va, hole_depth_va, depth_src_cd, project_no, count, recentcount, startdate, enddate, color]
# Index: []
#
# [0 rows x 47 columns]

# %%
# map = folium.Map(location=[39.25, -111.45], zoom_start=8)
# for index, row in df100.iterrows():
#     folium.Marker(location=[row['dec_lat_va'], row['dec_long_va']], 
#                   popup=row['site_no']).add_to(map)
# map

# %%
# map = folium.Map(location=[39.25, -111.45], zoom_start=8)
# for index, row in df100.iterrows():
#     folium.CircleMarker(location=[row['dec_lat_va'], row['dec_long_va']],radius=row['count']*1000000, color='blue', fill=True, fill_color='red')
# map

map = folium.Map(location=[39.25, -111.45], zoom_start=8)
for index, row in df100.iterrows():
    folium.CircleMarker(location=[row['dec_lat_va'], row['dec_long_va']],radius=row['count']/50, color=row['color'], fill=True, fill_color=row['color'], popup=row['site_no']).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fce4dfdf8f5dbccf981ae23ef3f81488 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fce4dfdf8f5dbccf981ae23ef3f81488&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fce4dfdf8f5dbccf981ae23ef3f81488 = L.map(
#                 &quot;map_fce4dfdf8f5dbccf981ae23ef3f81488&quot;,
#                 {
#                     center: [39.25, -111.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8332f9f87be15201b776629969119524 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fce4dfdf8f5dbccf981ae23ef3f81488);
#
#
#             var circle_marker_637b8aaa9d1201043fe695335f56707c = L.circleMarker(
#                 [37.00276485, -111.5076608],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 16.14, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fce4dfdf8f5dbccf981ae23ef3f81488);
#
#
#         var popup_fb26805fb4369bbaf13e88ebf51706f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7200d128730db32ec9885cd508fdd0e3 = $(`&lt;div id=&quot;html_7200d128730db32ec9885cd508fdd0e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;370010111302501&lt;/div&gt;`)[0];
#                 popup_fb26805fb4369bbaf13e88ebf51706f0.setContent(html_7200d128730db32ec9885cd508fdd0e3);
#
#
#
#         circle_marker_637b8aaa9d1201043fe695335f56707c.bindPopup(popup_fb26805fb4369bbaf13e88ebf51706f0)
#         ;
#
#
#
#
#             var circle_marker_94a6c029d8075db855db776a66051f1f = L.circleMarker(
#                 [37.0138747, -112.4632562],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.42, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fce4dfdf8f5dbccf981ae23ef3f81488);
#
#
#         var popup_f4340c06ac8b9be2f28e15d6c8bee4b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b000fbfc1ac8ebbaab15f9a719706235 = $(`&lt;div id=&quot;html_b000fbfc1ac8ebbaab15f9a719706235&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;370050112274501&lt;/div&gt;`)[0];
#                 popup_f4340c06ac8b9be2f28e15d6c8bee4b5.setContent(html_b000fbfc1ac8ebbaab15f9a719706235);
#
#
#
#         circle_marker_94a6c029d8075db855db776a66051f1f.bindPopup(popup_f4340c06ac8b9be2f28e15d6c8bee4b5)
#         ;
#
#
#
#
#             var circle_marker_732e0da3f464be17e833733cc3a87713 = L.circleMarker(
#                 [37.02359725, -111.6029419],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.56, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fce4dfdf8f5dbccf981ae23ef3f81488);
#
#
#         var popup_8fdbc73af29e75c606af761005bb9ab7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7cb7c910aa30cb35c29e1de12b082ac9 = $(`&lt;div id=&quot;html_7cb7c910aa30cb35c29e1de12b082ac9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;370125111360801&lt;/div&gt;`)[0];
#                 popup_8fdbc73af29e75c606af761005bb9ab7.setContent(html_7cb7c910aa30cb35c29e1de12b082ac9);
#
#
#
#         circle_marker_732e0da3f464be17e833733cc3a87713.bindPopup(popup_8fdbc73af29e75c606af761005bb9ab7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# dont forget that wells with no data has no NA start and end dates
